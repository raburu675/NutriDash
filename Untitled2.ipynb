# %%
from django.shortcuts import render
from django.http import HttpResponse
import plotly.express as px
import pandas as pd
from plotly.offline import plot # Import plot from plotly.offline

 # Your data for the chart
calorie_data = {
    'day' : ['Mon','Tue','Wed','Thurs','Fri','Sat','Sun'],
    'calories' : [2000,3200,1800,2500,2100,3000,1990]
}
# Create a Pandas DataFrame from your data
df = pd.DataFrame(calorie_data)


# Create the Plotly bar chart
fig = px.bar(df, x='day', y='calories',width=400 ,height=350)
fig.show()

# %%
import pandas as pd
import plotly.express as px
from django.shortcuts import render
from plotly.offline import plot

#nutrition data for a single day/meal
data = {
    'nutrients' : ['Calories','Proteins','Carbs'],
    'value' : [2500,1500,2000]
}
df = pd.DataFrame(data)

#calculate the total value
global_total = df['value'].sum()
print(global_total)

# Check to prevent division by zero in case of empty data

#calculate the % of the global total for each nutrient
df['percent_filled'] = (df['value'] / global_total) * 100
print(df)
df['percent_empty'] = 100 - df['percent_filled']

#reshape the dataframe for plotting(long format is best for stacked bars)
plot_df = pd.melt(df, id_varse=['nutrient'], value_vars=['percent_filled', 'percent'], var_name='type', value_name='percent')
#create the horizontal stacked bar charts with facets
fig = px.bar(
        plot_df,
        x='percent',
        y='type',
        color='type',
        orientation='h',
        facet_row='nutrient',
        height=300,
        color_discrete_map={'percent_filled': '#4caf50', 'percent_empty': '#e0e0e0'}
    )
# Customize the layout for a cleaner look
fig.update_layout(
    showlegend=False,
    margin=dict(l=0, r=20, t=20, b=0),
    yaxis=dict(visible=False, showticklabels=False),
    xaxis=dict(range=[0, 100])
)

# Add text labels (e.g., "30%") to the filled part of the bars
fig.update_traces(
    texttemplate='%{value:.0f}%',
    textposition='inside',
    insidetextanchor='start',
    textfont_color='white'
)
 # Customize the facet titles (the nutrient names)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.show()
# Out:
# 6000
#   nutrients  value  percent_filled
# 0  Calories   2500       41.666667
# 1  Proteins   1500       25.000000
# 2     Carbs   2000       33.333333
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 25
#      22 df['percent_empty'] = 100 - df['percent_filled']
#      24 #reshape the dataframe for plotting(long format is best for stacked bars)
# ---> 25 plot_df = pd.melt(df, id_varse=['nutrient'], value_vars=['percent_filled', 'percent'], var_name='type', value_name='percent')
#      26 #create the horizontal stacked bar charts with facets
#      27 fig = px.bar(
#      28         plot_df,
#      29         x='percent',
#    (...)     35         color_discrete_map={'percent_filled': '#4caf50', 'percent_empty': '#e0e0e0'}
#      36     )
#
# TypeError: melt() got an unexpected keyword argument 'id_varse'
